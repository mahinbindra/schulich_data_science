# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.formula.api import ols
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
house = pd.read_csv('/Users/mahinbindra/Downloads/kc_house_data.csv')

# %%
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180  \
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement
# 0      5650     1.0           0     0  ...      7        1180              0  \
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
plt.scatter(house['price'], house['sqft_living'])

# %%
sns.boxplot(data = house, y='price')
# Out:
# <Axes: ylabel='price'>

# %%
plt.scatter(house['price'], house['sqft_lot'])

# %%
sns.boxplot(data = house, y='grade')
# Out:
# <Axes: ylabel='grade'>

# %%
sns.barplot(data = house, x='condition', y='price')
# Out:
# <Axes: xlabel='condition', ylabel='price'>

# %%
sns.barplot(data = house, x='grade', y='price')
# Out:
# <Axes: xlabel='grade', ylabel='price'>

# %%
plt.scatter(house['sqft_above'],house['price'])
sns.set(rc={"figure.figsize":(10, 9)})

# %%
plt.scatter(house['sqft_basement'],house['price'])
sns.set(rc={"figure.figsize":(10, 9)})

# %%
plt.scatter(house['yr_built'],house['price'])
sns.set(rc={"figure.figsize":(10, 9)})

# %%
results = ols("price ~ bedrooms + floors + sqft_living", data=house).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.507
# Method:                 Least Squares   F-statistic:                     7402.
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):               0.00
# Time:                        20:58:46   Log-Likelihood:            -2.9997e+05
# No. Observations:               21613   AIC:                         5.999e+05
# Df Residuals:                   21609   BIC:                         6.000e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    7.586e+04   7658.046      9.905      0.000    6.08e+04    9.09e+04
# ...

# %%
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180  \
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement
# 0      5650     1.0           0     0  ...      7        1180              0  \
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
'y_hat = -5.699e+04bedrooms + 3239.7578floors + 313.2273sqft_living'
# Out:
# 'y_hat = -5.699e+04bedrooms + 3239.7578floors + 313.2273sqft_living'

# %%
7.586e+04 + (-5.699e+04*3) + (3239.7578*1) + (313.2273*1180)
# Out:
# 277737.97180000006

# %%
pred_vals = results.predict(house[['bedrooms','floors', 'sqft_living']])
pred_vals
# Out:
# 0        277746.303147
# 1        716371.985462
# 2        206309.041619
# 3        465077.659686
# 4        434359.945054
#              ...
# 21608    393855.368107
# 21609    577946.966834
# 21610    287855.620385
# 21611    412541.520162
# 21612    287855.620385
# Length: 21613, dtype: float64

# %%
res = pd.concat([pred_vals.to_frame().rename(columns={0:'y_hat'}),house['price']], axis = 1)
res
# Out:
#                y_hat     price
# 0      277746.303147  221900.0
# 1      716371.985462  538000.0
# 2      206309.041619  180000.0
# 3      465077.659686  604000.0
# 4      434359.945054  510000.0
# ...              ...       ...
# 21608  393855.368107  360000.0
# 21609  577946.966834  400000.0
# 21610  287855.620385  402101.0
# 21611  412541.520162  400000.0
# 21612  287855.620385  325000.0
#
# [21613 rows x 2 columns]

# %%
res['error'] = res['y_hat'] - res['price']

# %%
res.head(1)
# Out:
#            y_hat     price         error
# 0  277746.303147  221900.0  55846.303147

# %%
res['sq_error'] = res['error']**2

# %%
np.sqrt(res['sq_error'].mean())
# Out:
# 257814.81242133427

# %%
house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000  \
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000  \
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
plt.hist(res['error'])
# Out:
# (array([3.0000e+00, 2.0000e+00, 4.0000e+00, 2.5000e+01, 6.1000e+01,
#         3.1200e+02, 5.0320e+03, 1.5943e+04, 2.2800e+02, 3.0000e+00]),
#  array([-4183571.25957335, -3600436.9988779 , -3017302.73818245,
#         -2434168.477487  , -1851034.21679155, -1267899.95609611,
#          -684765.69540066,  -101631.43470521,   481502.82599024,
#          1064637.08668569,  1647771.34738114]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(house['price'])
# Out:
# (array([1.9021e+04, 2.1480e+03, 3.1600e+02, 9.0000e+01, 2.6000e+01,
#         4.0000e+00, 4.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([  75000.,  837500., 1600000., 2362500., 3125000., 3887500.,
#         4650000., 5412500., 6175000., 6937500., 7700000.]),
#  <BarContainer object of 10 artists>)

# %%
house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000  \
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000  \
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
plt.scatter(house['bedrooms'],res['error'])

# %%
plt.scatter(house['floors'],res['error'])

# %%
plt.scatter(house['sqft_living'],res['error'])

# %%
import scipy.stats as stats
fig = plt.figure()
ax = fig.add_subplot(111)
stats.probplot(res['error'], dist='norm', plot=ax)
# Out:
# ((array([-3.99703558, -3.78181236, -3.66408326, ...,  3.66408326,
#           3.78181236,  3.99703558]),
#   array([-4183571.25957335, -4120292.05411166, -4046762.07152014, ...,
#           1127584.27714835,  1226374.24964934,  1647771.34738114])),
#  (236048.03439392045, 2.6861163062362583e-08, 0.9154090672465339))

# %%
infl = results.get_influence()
print(infl.summary_frame())
# Out:
#        dfb_Intercept  dfb_bedrooms  dfb_floors  dfb_sqft_living       cooks_d
# 0          -0.001339     -0.000266    0.000885         0.001006  1.282241e-06  \
# 1          -0.000592      0.003931   -0.003612        -0.003041  1.451578e-05
# 2          -0.001197      0.000565    0.000326         0.000362  4.686854e-07
# 3           0.000557      0.003247   -0.003282        -0.001186  8.953309e-06
# 4           0.001972     -0.000422   -0.001639         0.000039  1.888653e-06
# ...              ...           ...         ...              ...           ...
# 21608       0.000931     -0.000049   -0.002867         0.001284  2.326437e-06
# 21609       0.003736     -0.003219   -0.004374         0.002136  1.297609e-05
# 21610       0.002295     -0.002822    0.004226        -0.002393  1.198833e-05
# 21611       0.000009      0.000025   -0.000396         0.000237  7.435703e-08
# 21612       0.000746     -0.000918    0.001374        -0.000778  1.267266e-06
#
# ...

# %%
infl.summary_frame()
# Out:
#        dfb_Intercept  dfb_bedrooms  dfb_floors  dfb_sqft_living       cooks_d
# 0          -0.001339     -0.000266    0.000885         0.001006  1.282241e-06  \
# 1          -0.000592      0.003931   -0.003612        -0.003041  1.451578e-05
# 2          -0.001197      0.000565    0.000326         0.000362  4.686854e-07
# 3           0.000557      0.003247   -0.003282        -0.001186  8.953309e-06
# 4           0.001972     -0.000422   -0.001639         0.000039  1.888653e-06
# ...              ...           ...         ...              ...           ...
# 21608       0.000931     -0.000049   -0.002867         0.001284  2.326437e-06
# 21609       0.003736     -0.003219   -0.004374         0.002136  1.297609e-05
# 21610       0.002295     -0.002822    0.004226        -0.002393  1.198833e-05
# 21611       0.000009      0.000025   -0.000396         0.000237  7.435703e-08
# 21612       0.000746     -0.000918    0.001374        -0.000778  1.267266e-06
#
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))
fig = sm.graphics.influence_plot(results, ax=ax, criterion='cooks')

# %%
house_2 = house.copy()

# %%
house_2.drop(15870, inplace=True)

# %%
results = ols("price ~ bedrooms + floors + sqft_living", data=house_2).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.508
# Method:                 Least Squares   F-statistic:                     7443.
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):               0.00
# Time:                        21:15:59   Log-Likelihood:            -2.9992e+05
# No. Observations:               21612   AIC:                         5.999e+05
# Df Residuals:                   21608   BIC:                         5.999e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    8.656e+04   7769.775     11.141      0.000    7.13e+04    1.02e+05
# ...

# %%
infl = results.get_influence()
print(infl.summary_frame())
# Out:
#        dfb_Intercept  dfb_bedrooms  dfb_floors  dfb_sqft_living       cooks_d
# 0          -0.001283     -0.000278    0.000872         0.000994  1.247940e-06  \
# 1          -0.000790      0.004157   -0.003675        -0.003233  1.538377e-05
# 2          -0.001338      0.000649    0.000363         0.000373  5.856016e-07
# 3           0.000391      0.003473   -0.003366        -0.001354  9.677872e-06
# 4           0.001943     -0.000428   -0.001628         0.000052  1.864873e-06
# ...              ...           ...         ...              ...           ...
# 21608       0.000916     -0.000049   -0.002863         0.001268  2.320502e-06
# 21609       0.003785     -0.003298   -0.004320         0.002219  1.282918e-05
# 21610       0.002325     -0.002841    0.004098        -0.002179  1.143589e-05
# 21611       0.000008      0.000026   -0.000404         0.000238  7.759068e-08
# 21612       0.000706     -0.000863    0.001245        -0.000662  1.055099e-06
#
# ...

# %%
infl.summary_frame()
# Out:
#        dfb_Intercept  dfb_bedrooms  dfb_floors  dfb_sqft_living       cooks_d
# 0          -0.001283     -0.000278    0.000872         0.000994  1.247940e-06  \
# 1          -0.000790      0.004157   -0.003675        -0.003233  1.538377e-05
# 2          -0.001338      0.000649    0.000363         0.000373  5.856016e-07
# 3           0.000391      0.003473   -0.003366        -0.001354  9.677872e-06
# 4           0.001943     -0.000428   -0.001628         0.000052  1.864873e-06
# ...              ...           ...         ...              ...           ...
# 21608       0.000916     -0.000049   -0.002863         0.001268  2.320502e-06
# 21609       0.003785     -0.003298   -0.004320         0.002219  1.282918e-05
# 21610       0.002325     -0.002841    0.004098        -0.002179  1.143589e-05
# 21611       0.000008      0.000026   -0.000404         0.000238  7.759068e-08
# 21612       0.000706     -0.000863    0.001245        -0.000662  1.055099e-06
#
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))
fig = sm.graphics.influence_plot(results, ax=ax, criterion='cooks')

# %%
house_2.drop(7252, inplace=True)

# %%
results = ols("price ~ bedrooms + floors + sqft_living", data=house_2).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.506
# Model:                            OLS   Adj. R-squared:                  0.505
# Method:                 Least Squares   F-statistic:                     7363.
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):               0.00
# Time:                        21:20:15   Log-Likelihood:            -2.9978e+05
# No. Observations:               21611   AIC:                         5.996e+05
# Df Residuals:                   21607   BIC:                         5.996e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    8.766e+04   7722.700     11.351      0.000    7.25e+04    1.03e+05
# ...

# %%
infl = results.get_influence()
print(infl.summary_frame())
# Out:
#        dfb_Intercept  dfb_bedrooms  dfb_floors  dfb_sqft_living       cooks_d
# 0          -0.001333     -0.000292    0.000904         0.001037  1.348969e-06  \
# 1          -0.000785      0.004149   -0.003658        -0.003234  1.529750e-05
# 2          -0.001435      0.000694    0.000388         0.000403  6.733841e-07
# 3           0.000392      0.003483   -0.003373        -0.001358  9.729861e-06
# 4           0.001950     -0.000429   -0.001633         0.000051  1.877702e-06
# ...              ...           ...         ...              ...           ...
# 21608       0.000987     -0.000055   -0.003089         0.001370  2.701458e-06
# 21609       0.003813     -0.003323   -0.004353         0.002233  1.302693e-05
# 21610       0.002299     -0.002799    0.004052        -0.002162  1.117464e-05
# 21611       0.000009      0.000028   -0.000449         0.000265  9.585051e-08
# 21612       0.000669     -0.000815    0.001179        -0.000629  9.463442e-07
#
# ...

# %%
infl.summary_frame()
# Out:
#        dfb_Intercept  dfb_bedrooms  dfb_floors  dfb_sqft_living       cooks_d
# 0          -0.001333     -0.000292    0.000904         0.001037  1.348969e-06  \
# 1          -0.000785      0.004149   -0.003658        -0.003234  1.529750e-05
# 2          -0.001435      0.000694    0.000388         0.000403  6.733841e-07
# 3           0.000392      0.003483   -0.003373        -0.001358  9.729861e-06
# 4           0.001950     -0.000429   -0.001633         0.000051  1.877702e-06
# ...              ...           ...         ...              ...           ...
# 21608       0.000987     -0.000055   -0.003089         0.001370  2.701458e-06
# 21609       0.003813     -0.003323   -0.004353         0.002233  1.302693e-05
# 21610       0.002299     -0.002799    0.004052        -0.002162  1.117464e-05
# 21611       0.000009      0.000028   -0.000449         0.000265  9.585051e-08
# 21612       0.000669     -0.000815    0.001179        -0.000629  9.463442e-07
#
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))
fig = sm.graphics.influence_plot(results, ax=ax, criterion='cooks')

# %%
house_2.drop(3914, inplace=True)
house_2.drop(9254, inplace=True)

# %%
results = ols("price ~ bedrooms + floors + sqft_living", data=house_2).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.503
# Model:                            OLS   Adj. R-squared:                  0.503
# Method:                 Least Squares   F-statistic:                     7286.
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):               0.00
# Time:                        21:28:17   Log-Likelihood:            -2.9949e+05
# No. Observations:               21609   AIC:                         5.990e+05
# Df Residuals:                   21605   BIC:                         5.990e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     8.89e+04   7630.549     11.650      0.000    7.39e+04    1.04e+05
# ...

# %%
infl = results.get_influence()
print(infl.summary_frame())
# Out:
#        dfb_Intercept  dfb_bedrooms  dfb_floors  dfb_sqft_living       cooks_d
# 0          -0.001412     -0.000312    0.000954         0.001102  1.513211e-06  \
# 1          -0.000781      0.004147   -0.003640        -0.003241  1.524261e-05
# 2          -0.001584      0.000763    0.000427         0.000448  8.216299e-07
# 3           0.000396      0.003513   -0.003400        -0.001369  9.900328e-06
# 4           0.001972     -0.000433   -0.001651         0.000051  1.920273e-06
# ...              ...           ...         ...              ...           ...
# 21608       0.001121     -0.000067   -0.003511         0.001561  3.490761e-06
# 21609       0.003870     -0.003374   -0.004419         0.002263  1.342535e-05
# 21610       0.002256     -0.002736    0.003979        -0.002134  1.076354e-05
# 21611       0.000010      0.000032   -0.000528         0.000312  1.325031e-07
# 21612       0.000606     -0.000734    0.001068        -0.000573  7.750898e-07
#
# ...

# %%
infl.summary_frame()
# Out:
#        dfb_Intercept  dfb_bedrooms  dfb_floors  dfb_sqft_living       cooks_d
# 0          -0.001412     -0.000312    0.000954         0.001102  1.513211e-06  \
# 1          -0.000781      0.004147   -0.003640        -0.003241  1.524261e-05
# 2          -0.001584      0.000763    0.000427         0.000448  8.216299e-07
# 3           0.000396      0.003513   -0.003400        -0.001369  9.900328e-06
# 4           0.001972     -0.000433   -0.001651         0.000051  1.920273e-06
# ...              ...           ...         ...              ...           ...
# 21608       0.001121     -0.000067   -0.003511         0.001561  3.490761e-06
# 21609       0.003870     -0.003374   -0.004419         0.002263  1.342535e-05
# 21610       0.002256     -0.002736    0.003979        -0.002134  1.076354e-05
# 21611       0.000010      0.000032   -0.000528         0.000312  1.325031e-07
# 21612       0.000606     -0.000734    0.001068        -0.000573  7.750898e-07
#
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))
fig = sm.graphics.influence_plot(results, ax=ax, criterion='cooks')

# %%
house_3 = house_2.copy()

# %%
dummies_condition = pd.get_dummies(house_3.condition, dtype = int)
dummies_condition.rename(columns={1:'worse', 2:'bad', 3:'neutral', 4:'good', 5:'best'}, inplace = True)
house_3 = pd.concat([house_3,dummies_condition], axis = 1)
house_3
# Out:
#                id             date     price  bedrooms  bathrooms
# 0      7129300520  20141013T000000  221900.0         3       1.00  \
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  zipcode      lat
# 0             1180      5650     1.0           0     0  ...    98178  47.5112  \
# ...

# %%
house_3['total_sqft'] = house_3['sqft_living'] + house_3['sqft_lot']

# %%
house_3['date'] = pd.to_datetime(house_3['date'])

# %%
results = ols("price ~ bedrooms + floors + sqft_living + condition", data=house_3).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.512
# Model:                            OLS   Adj. R-squared:                  0.512
# Method:                 Least Squares   F-statistic:                     5659.
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):               0.00
# Time:                        21:40:57   Log-Likelihood:            -2.9930e+05
# No. Observations:               21609   AIC:                         5.986e+05
# Df Residuals:                   21604   BIC:                         5.986e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -1.104e+05   1.27e+04     -8.721      0.000   -1.35e+05   -8.55e+04
# ...

# %%
dummies_view = pd.get_dummies(house_3.view, dtype = int)
dummies_view.rename(columns={0:'worst view', 1:'bad view', 2:'neutral view', 3:'good view', 4:'best view'}, inplace = True)
house_3 = pd.concat([house_3,dummies_view], axis = 1)
house_3
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180  \
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  worse  bad  neutral  good
# ...

# %%
results = ols("price ~ bedrooms + floors + sqft_living + view", data=house_3).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.542
# Model:                            OLS   Adj. R-squared:                  0.542
# Method:                 Least Squares   F-statistic:                     6400.
# Date:                Tue, 11 Jul 2023   Prob (F-statistic):               0.00
# Time:                        15:09:58   Log-Likelihood:            -2.9860e+05
# No. Observations:               21609   AIC:                         5.972e+05
# Df Residuals:                   21604   BIC:                         5.972e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     7.73e+04   7326.963     10.550      0.000    6.29e+04    9.17e+04
# ...

# %%
house_4 = house_3.copy()

# %%
house_4['grade'].unique()
# Out:
# array([ 7,  6,  8, 11,  9,  5, 10, 12,  4,  3, 13,  1])

# %%
dummies_grade = pd.get_dummies(house_4.grade, dtype = int)
dummies_grade.rename(columns={1:'worst grade', 3:'terrible grade', 4:'bad grade', 5:'ok grade', 6:'neutral grade', 7:'good grade', 8:'better grade', 9:'great grade', 10:'excellent grade', 11: 'outstanding grade', 12:'best grade'}, inplace = True)
house_4 = pd.concat([house_4,dummies_grade], axis = 1)
house_4
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180  \
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  bad grade  ok grade
# ...

# %%
results = ols("price ~ bedrooms + floors + sqft_living + grade", data=house_4).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.546
# Model:                            OLS   Adj. R-squared:                  0.546
# Method:                 Least Squares   F-statistic:                     6500.
# Date:                Tue, 11 Jul 2023   Prob (F-statistic):               0.00
# Time:                        16:03:46   Log-Likelihood:            -2.9850e+05
# No. Observations:               21609   AIC:                         5.970e+05
# Df Residuals:                   21604   BIC:                         5.971e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -4.844e+05   1.46e+04    -33.207      0.000   -5.13e+05   -4.56e+05
# ...

# %%
daily_dataset = house_4.set_index('date').resample("2D").agg({'sqft_living':'mean','floors':'mean','bedrooms':'mean','price':'mean', 'grade':'mean'}).ffill()

# %%
daily_dataset
# Out:
#             sqft_living    floors  bedrooms         price     grade
# date
# 2014-05-02  2075.633803  1.450704  3.380282  5.229117e+05  7.788732
# 2014-05-04  2271.898876  1.556180  3.505618  5.806999e+05  7.865169
# 2014-05-06  2084.926136  1.468750  3.431818  5.373479e+05  7.653409
# 2014-05-08  2077.895062  1.518519  3.345679  5.318822e+05  7.728395
# 2014-05-10  2075.714286  1.785714  3.714286  5.164786e+05  7.714286
# ...                 ...       ...       ...           ...       ...
# 2015-05-19  1870.000000  1.500000  5.000000  4.500000e+05  7.000000
# 2015-05-21  1870.000000  1.500000  5.000000  4.500000e+05  7.000000
# 2015-05-23  1390.000000  1.000000  2.000000  4.455000e+05  6.000000
# 2015-05-25  1390.000000  1.000000  2.000000  4.455000e+05  6.000000
# 2015-05-27  3750.000000  2.000000  4.000000  1.310000e+06  8.000000
#
# [196 rows x 5 columns]

# %%
results = ols("price ~ bedrooms + floors + sqft_living + grade", data=daily_dataset).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.713
# Model:                            OLS   Adj. R-squared:                  0.707
# Method:                 Least Squares   F-statistic:                     118.9
# Date:                Tue, 11 Jul 2023   Prob (F-statistic):           9.97e-51
# Time:                        15:53:36   Log-Likelihood:                -2388.1
# No. Observations:                 196   AIC:                             4786.
# Df Residuals:                     191   BIC:                             4803.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    2.463e+05   1.18e+05      2.095      0.038    1.44e+04    4.78e+05
# ...

# %%
categorical_features = ['grade']
numerical_features = ['sqft_living', 'bedrooms', 'floors']
target = 'price'

# %%
house_4[['bedrooms','floors','sqft_living','grade','price']]
# Out:
#        bedrooms  floors  sqft_living  grade     price
# 0             3     1.0         1180      7  221900.0
# 1             3     2.0         2570      7  538000.0
# 2             2     1.0          770      6  180000.0
# 3             4     1.0         1960      7  604000.0
# 4             3     1.0         1680      8  510000.0
# ...         ...     ...          ...    ...       ...
# 21608         3     3.0         1530      8  360000.0
# 21609         4     2.0         2310      8  400000.0
# 21610         2     2.0         1020      7  402101.0
# 21611         3     2.0         1600      8  400000.0
# 21612         2     2.0         1020      7  325000.0
#
# [21609 rows x 5 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler
from sklearn.linear_model import LinearRegression, ElasticNet, Ridge, Lasso
from sklearn.impute import SimpleImputer
import numpy as np

# %%
X_train, X_test, y_train, y_test = train_test_split(house_4[categorical_features + numerical_features]
                                                     ,house_4[target],
                                                    test_size = 0.3, random_state=1234)

# %%
cat_transformer = Pipeline(steps = [('onehot', OneHotEncoder(handle_unknown='ignore'))])
num_transformer = Pipeline(steps = [('scaler', StandardScaler())])

# %%
preprocessor = ColumnTransformer(transformers = [('cat',cat_transformer, categorical_features),
                                                 ('num', num_transformer, numerical_features)])

# %%
linear_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
linear_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['grade']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sqft_living', 'bedrooms',
#                                                    'floors'])])),
#                 ('regressor', LinearRegression())])

# %%
pred = linear_regression.predict(X_test)

# %%
pred
# Out:
# array([ 243336.10251038,  516492.32786239,  246782.97004241, ...,
#        1502192.40356884,  667773.1357165 ,  399090.16729877])

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(pred,y_test))
# Out:
# 226481.9779320926

# %%
ridge_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', Ridge(alpha=3.0))
])

# %%
ridge_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['grade']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sqft_living', 'bedrooms',
#                                                    'floors'])])),
#                 ('regressor', Ridge(alpha=3.0))])

# %%
ridge_pred = ridge_regression.predict(X_test)

# %%
np.sqrt(mean_squared_error(ridge_pred,y_test))
# Out:
# 232231.33173843575

# %%
lasso_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', Lasso(alpha=1.0))
])

# %%
lasso_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['grade']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sqft_living', 'bedrooms',
#                                                    'floors'])])),
#                 ('regressor', Lasso())])

# %%
lasso_pred = lasso_regression.predict(X_test)

# %%
np.sqrt(mean_squared_error(lasso_pred, y_test))
# Out:
# 226482.73641192625

# %%
elasticnet_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', ElasticNet(alpha=1.0, l1_ratio=0.8))
])

# %%
elasticnet_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['grade']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sqft_living', 'bedrooms',
#                                                    'floors'])])),
#                 ('regressor', ElasticNet(l1_ratio=0.8))])

# %%
elasticnet_pred = elasticnet_regression.predict(X_test)

# %%
np.sqrt(mean_squared_error(elasticnet_pred, y_test))
# Out:
# 243209.50122676085

# %%
y_test
# Out:
# 14917     530000.0
# 19875     430000.0
# 2701      220000.0
# 19496     350000.0
# 16020    1280000.0
#            ...
# 11554     400000.0
# 6052      730000.0
# 4399     1150000.0
# 9297      449228.0
# 5325      485000.0
# Name: price, Length: 6483, dtype: float64

# %%
X_test
# Out:
#        grade  sqft_living  bedrooms  floors
# 14917      6          760         2     1.0
# 19875      8         2020         3     2.0
# 2701       6          780         2     1.0
# 19496      7         1920         3     1.0
# 16020      9         3010         4     2.0
# ...      ...          ...       ...     ...
# 11554      7         2220         3     2.0
# 6052       9         3460         3     2.0
# 4399      11         4400         4     2.0
# 9297       8         3020         5     1.0
# 5325       7         1670         3     1.5
#
# [6483 rows x 4 columns]

# %%
ridge_pred_net = pd.concat([pd.DataFrame(ridge_pred).rename(columns={0:'pred'}),y_test.reset_index().drop('index',axis=1).rename(columns={0:'actual'})], axis=1)
ridge_pred_net['res'] = ridge_pred_net['pred'] - ridge_pred_net['price']
plt.scatter(X_test['sqft_living'],ridge_pred_net['res'])

# %%
elastic_net_pred = pd.concat([pd.DataFrame(elasticnet_pred).rename(columns={0:'pred'}),y_test.reset_index().drop('index',axis=1).rename(columns={0:'actual'})], axis=1)
elastic_net_pred['res'] = elastic_net_pred['pred'] - elastic_net_pred['price']
plt.scatter(X_test['sqft_living'],elastic_net_pred['res'])

# %%
lasso_pred_net = pd.concat([pd.DataFrame(lasso_pred).rename(columns={0:'pred'}),y_test.reset_index().drop('index',axis=1).rename(columns={0:'actual'})], axis=1)
lasso_pred_net['res'] = lasso_pred_net['pred'] - lasso_pred_net['price']
plt.scatter(X_test['sqft_living'],lasso_pred_net['res'])

# %%
linear_pred_net = pd.concat([pd.DataFrame(pred).rename(columns={0:'pred'}),y_test.reset_index().drop('index',axis=1).rename(columns={0:'actual'})], axis=1)
linear_pred_net['res'] = linear_pred_net['pred'] - linear_pred_net['price']
plt.scatter(X_test['sqft_living'],linear_pred_net['res'])

# %% [markdown]
# **Q. Build a regression model to predict the price of a house. You may choose between Ordinary Least Squares Regression, LASSO, Ridge or Elastic Net.**
# - You may need to clean and transform the data, including feature engineering, creating dummy variables, or using dimensionality reduction.**
# - Be sure to explain why you chose the approach you did, and why it's the best approach for the data provided.**
#
#
# A. Before building the model to predict the price of the house, it was essential to clean the data and remove any outliers if needed. Since there were no missing or NaN values throughout the dataset, there wasn't a need to impute any values. Although based on the various bar plots and scatterplots I developed upfront, it was evident that multiple outliers were present in the data. However, clarification on which values have a more significant influence is optional. Hence I decided not to drop those values immediately but create an influence plot to assess their impact on the data.
# Post-creating the influence plot using the key attributes that significantly impact the price of a house gave a clear picture of the outliers with solid influence. Hence, I dropped those values, in this case, index values 15870, 7252, 3914 and 9254.
# Post that, I created dummy variables for the condition, view and grade columns, as these factors can impact the price of the house. I also made another column named 'total_sqft' to calculate the total area of the house in the sqft. Using the dummy variables and total_sqft column, I updated my equation to assess which attribute has a relatively higher impact on the accuracy of the OLS model, in this case, 'grade'.
# I also created a variable named 'daily_dataset', which consisted of the mean values of all critical attributes and resampled the data every two days, using which I calculated the results for my OLS model to attain an R-squared of 0.713 over the original value of 0.507, indicating that the methods mentioned above improved the efficiency by ~21%.
#
# Ultimately, I segregated all my key attributes as categorical or numerical to create train and test variables to apply regression and develop different models potentially - in this case, linear, LASSO, ridge and elastic net regression to eventually assess which model works best for my dataset in predicting the price of the house.
# Based on the results, I can conclude that linear regression models works the best. *[rationale explained below]*

# %% [markdown]
# **Q. Evaluate the model using techniques covered in class and explain the results. How do you know this is the best model you can build, given the tools you have?**
#
# A. To assess which model works best for my dataset in predicting the price of the house I calculated the mean squared error for each model. The MSE results for each of the model are as follows.
# OLS Regression Model - 257814.81242133427
# Linear Regression Model - 226481.9779320926
# LASSO Regression Model - 226482.73641192625
# Ridge Regression Model - 232231.33173843575
# Elastic Net Regression Model - 243209.50122676085
#
# The above mentioned results indicate that OLS regression model has the highest MSE value and hence performs the worst in predicting the price of a house as compared to other models. Another observation we can make is that though linear and LASSO regression have an almost similar MSE, they perform much better than other. Pressure testing further, we can conculde that the linear regression model will be more accurately be able to predict the price of the house given the attributes 'number of bedrooms (bedrooms)', 'living area in sqft (sqft_living)', 'number of floors (floors)' and 'quality of materials and workmanship used to build the house (grade)'.
