# %%
from gurobipy import Model, GRB, quicksum
import numpy as np
import pandas as pd

# %%
# Load the data
demand_distribution_df = pd.read_csv("/Users/mahinbindra/Downloads/distributions (1).csv")
cost_matrix_df = pd.read_csv("/Users/mahinbindra/Downloads/cost_matrix (1).csv")

# %%
# Initialize the model
model = Model("Inventory_Transshipment")

# %%
# Number of stores
num_stores = len(cost_matrix_df)

# %%
# Set up scenario probabilities and demands for each scenario
num_scenarios = 10  # You should define this based on your scenario data
prob_scenario = 1 / num_scenarios  # Equal probability for each scenario as a placeholder
scenario_demands = np.random.choice(demand_distribution_df['Mean'], num_scenarios)  # Placeholder for scenario demands

# %%
# Cost parameters
ordering_cost = 24.44
holding_cost = 25.55  # This may represent the combination of overage and underage costs per unit
cost_matrix = cost_matrix_df.values

# %%
# First stage variables
order_qty = model.addVars(num_stores, vtype=GRB.CONTINUOUS, name="Order_Quantity")

# %%
# Second stage variables
overage = model.addVars(num_stores, num_scenarios, vtype=GRB.CONTINUOUS, name="Overage")
underage = model.addVars(num_stores, num_scenarios, vtype=GRB.CONTINUOUS, name="Underage")
transshipment = model.addVars(num_stores, num_stores, num_scenarios, vtype=GRB.CONTINUOUS, name="Transshipment")

# %%
# Objective Function
model.setObjective(
    (1 / num_scenarios) * quicksum(
        ordering_cost * order_qty[i] +
        holding_cost * overage[i, k] +
        holding_cost * underage[i, k] +
        quicksum(cost_matrix[i, j] * transshipment[i, j, k] for j in range(num_stores) if i != j)
        for i in range(num_stores) for k in range(num_scenarios)),
    GRB.MINIMIZE)

# %%
# First stage constraints
for i in range(num_stores):
    model.addConstr(order_qty[i] >= 0, name=f"Non_Negativity_y_{i}")

# Second stage constraints
for k in range(num_scenarios):
    for i in range(num_stores):
        # Overage and underage constraints
        model.addConstr(overage[i, k] >= order_qty[i] - scenario_demands[k], name=f"Overage_{i}_{k}")
        model.addConstr(underage[i, k] >= scenario_demands[k] - order_qty[i], name=f"Underage_{i}_{k}")

        # Transshipment constraints
        for j in range(num_stores):
            if i != j:
                model.addConstr(transshipment[i, j, k] <= order_qty[i] - overage[i, k], name=f"Transshipment_{i}_{j}_{k}")

# %%
# Optimize the model
model.optimize()
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2415 rows, 2565 columns and 6915 nonzeros
# Model fingerprint: 0x6010b5c8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+01, 1e+02]
# Presolve removed 2115 rows and 2250 columns
# Presolve time: 0.01s
# Presolved: 300 rows, 465 columns, 750 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.580639e+04   0.000000e+00      0s
#      150    3.9273994e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 150 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  3.927399361e+04

# %%
# Output solution
if model.status == GRB.OPTIMAL:
    print("Optimal solution found.")
    # Retrieving and printing the decision variables may be added here as needed
else:
    print("No optimal solution found or there was an issue with the optimization.")
# Out:
# Optimal solution found.

# %%
import pandas as pd
import numpy as np
from gurobipy import Model, GRB, quicksum

# Load the demand distribution data
demand_distribution_df = pd.read_csv("/Users/mahinbindra/Downloads/distributions (1).csv")

# Parameters
num_stores = len(demand_distribution_df)
num_trials = 50
num_scenarios_per_trial = 100
ordering_cost = 24.44
per_unit_overage_cost = 25.55  # Cost per unit of unsold inventory
per_unit_underage_cost = 25.55  # Opportunity cost per unit of excess demand

# Function to run a single trial
def run_trial():
    model = Model("Inventory_Optimization_No_Transshipment")

    # Generate demand scenarios
    demand_scenarios = np.array([
        np.random.binomial(n=row['n'], p=row['p'], size=num_scenarios_per_trial)
        for _, row in demand_distribution_df.iterrows()
    ])

    # Decision Variables
    order_qty = model.addVars(num_stores, vtype=GRB.CONTINUOUS, name="Order_Quantity")
    overage = model.addVars(num_stores, num_scenarios_per_trial, vtype=GRB.CONTINUOUS, name="Overage")
    underage = model.addVars(num_stores, num_scenarios_per_trial, vtype=GRB.CONTINUOUS, name="Underage")

    # Objective Function
    model.setObjective(
        (1 / num_scenarios_per_trial) * quicksum(
            ordering_cost * order_qty[i] +
            per_unit_overage_cost * overage[i, s] +
            per_unit_underage_cost * underage[i, s]
            for i in range(num_stores) for s in range(num_scenarios_per_trial)),
        GRB.MINIMIZE)

    # Constraints
    for i in range(num_stores):
        for s in range(num_scenarios_per_trial):
            model.addConstr(overage[i, s] >= order_qty[i] - demand_scenarios[i, s], name=f"Overage_{i}_{s}")
            model.addConstr(underage[i, s] >= demand_scenarios[i, s] - order_qty[i], name=f"Underage_{i}_{s}")

    # Solve the model
    model.optimize()

    # Check if the model has been solved to optimality
    if model.status == GRB.OPTIMAL:
        # Record the optimal cost for this trial
        return model.objVal
    else:
        raise Exception("Optimization was unsuccessful or did not reach optimality.")

# Run all trials and record the costs
trial_costs = [run_trial() for _ in range(num_trials)]

# Calculate the average cost associated with the optimal plan
average_cost = np.mean(trial_costs)
print(f"The average cost associated with the optimal plan over {num_trials} trials is: {average_cost}")
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x8369159b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.428400e+04   0.000000e+00      0s
#      274    3.3981850e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.1810000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      277    3.3981850e+04   0.000000e+00   1.181000e+00      0s
#      284    3.3981850e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 284 iterations and 0.02 seconds (0.01 work units)
# Optimal objective  3.398185050e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x25baa85b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.463000e+04   0.000000e+00      0s
#      275    3.3903483e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.0575000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      278    3.3903483e+04   0.000000e+00   3.057500e+00      0s
#      294    3.3903483e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 294 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.390348300e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x415e6bd6
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.399300e+04   0.000000e+00      0s
#      269    3.3936099e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.0355000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      272    3.3936099e+04   0.000000e+00   2.035500e+00      0s
#      283    3.3936099e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 283 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.393609900e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xa7b88552
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.493900e+04   0.000000e+00      0s
#      279    3.3935684e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.1980000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      282    3.3935684e+04   0.000000e+00   1.198000e+00      0s
#      289    3.3935684e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 289 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.393568450e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xe3d478dd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.401800e+04   0.000000e+00      0s
#      268    3.3835792e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.2115000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      271    3.3835792e+04   0.000000e+00   2.211500e+00      0s
#      283    3.3835792e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 283 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.383579250e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xfda48930
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.374400e+04   0.000000e+00      0s
#      267    3.3907403e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.5550000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      270    3.3907403e+04   0.000000e+00   2.555000e+00      0s
#      284    3.3907403e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 284 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.390740350e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x732b73b8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.523200e+04   0.000000e+00      0s
#      282    3.3880320e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.8765000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      285    3.3880320e+04   0.000000e+00   1.876500e+00      0s
#      296    3.3880320e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 296 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.388032050e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xa6c52a09
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.542800e+04   0.000000e+00      0s
#      287    3.3892769e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.5635000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      290    3.3892769e+04   0.000000e+00   2.563500e+00      0s
#      304    3.3892769e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 304 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.389276900e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x4f11d06f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.432900e+04   0.000000e+00      0s
#      274    3.3882444e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7005000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      277    3.3882444e+04   0.000000e+00   1.700500e+00      0s
#      287    3.3882444e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 287 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.388244400e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x7fde68e4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.502300e+04   0.000000e+00      0s
#      281    3.3901393e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7005000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      284    3.3901393e+04   0.000000e+00   1.700500e+00      0s
#      294    3.3901393e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 294 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.390139350e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xa6d30e60
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.411600e+04   0.000000e+00      0s
#      271    3.3884647e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7005000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      274    3.3884647e+04   0.000000e+00   1.700500e+00      0s
#      283    3.3884647e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 283 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.388464700e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x6e4df2ce
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.463200e+04   0.000000e+00      0s
#      275    3.3865007e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.2115000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      278    3.3865007e+04   0.000000e+00   2.211500e+00      0s
#      290    3.3865007e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 290 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.386500750e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x1e05044a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.525000e+04   0.000000e+00      0s
#      285    3.3936882e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.5450000e-01      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      288    3.3936882e+04   0.000000e+00   8.545000e-01      0s
#      293    3.3936882e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 293 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.393688250e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x73020842
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.491600e+04   0.000000e+00      0s
#      281    3.3966202e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.8680000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      284    3.3966202e+04   0.000000e+00   1.868000e+00      0s
#      295    3.3966202e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 295 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.396620250e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x51e70aa4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.524600e+04   0.000000e+00      0s
#      284    3.3905632e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.5450000e-01      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      287    3.3905632e+04   0.000000e+00   8.545000e-01      0s
#      292    3.3905632e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 292 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.390563200e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x38e07f01
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.480000e+04   0.000000e+00      0s
#      277    3.3886117e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.0575000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      280    3.3886117e+04   0.000000e+00   3.057500e+00      0s
#      295    3.3886117e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 295 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.388611750e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x459d93cc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.574300e+04   0.000000e+00      0s
#      286    3.3944899e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.8595000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      289    3.3944899e+04   0.000000e+00   1.859500e+00      0s
#      299    3.3944899e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 299 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.394489950e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x71e54c32
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.378000e+04   0.000000e+00      0s
#      267    3.3890884e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7005000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      270    3.3890884e+04   0.000000e+00   1.700500e+00      0s
#      280    3.3890884e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 280 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.389088400e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xadcdc072
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.554200e+04   0.000000e+00      0s
#      288    3.3912380e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.5330000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      291    3.3912380e+04   0.000000e+00   1.533000e+00      0s
#      300    3.3912380e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 300 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.391238000e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x43ee4d9d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.490200e+04   0.000000e+00      0s
#      278    3.3894628e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.2115000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      281    3.3894628e+04   0.000000e+00   2.211500e+00      0s
#      293    3.3894628e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 293 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.389462850e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x24a0d43e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.544900e+04   0.000000e+00      0s
#      285    3.3899156e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.8765000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      288    3.3899156e+04   0.000000e+00   1.876500e+00      0s
#      299    3.3899156e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 299 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.389915650e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xa42653db
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.401400e+04   0.000000e+00      0s
#      270    3.3898532e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.8680000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      273    3.3898532e+04   0.000000e+00   1.868000e+00      0s
#      283    3.3898532e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 283 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.389853200e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xe1faf7dd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.511700e+04   0.000000e+00      0s
#      279    3.3802929e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.7225000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      282    3.3802929e+04   0.000000e+00   2.722500e+00      0s
#      297    3.3802929e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 297 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.380292950e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x6f8eafe2
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.564000e+04   0.000000e+00      0s
#      287    3.3834180e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7005000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      290    3.3834180e+04   0.000000e+00   1.700500e+00      0s
#      300    3.3834180e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 300 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.383418000e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x9a9bcc31
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.406200e+04   0.000000e+00      0s
#      270    3.3916945e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.3790000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      273    3.3916945e+04   0.000000e+00   2.379000e+00      0s
#      285    3.3916945e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 285 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.391694500e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x99078a3c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.502600e+04   0.000000e+00      0s
#      278    3.3914239e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.2030000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      281    3.3914239e+04   0.000000e+00   2.203000e+00      0s
#      293    3.3914239e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 293 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.391423950e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x96e85714
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.579800e+04   0.000000e+00      0s
#      287    3.3927940e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0220000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      290    3.3927940e+04   0.000000e+00   1.022000e+00      0s
#      296    3.3927940e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 296 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.392794000e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xff371fda
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.546700e+04   0.000000e+00      0s
#      285    3.3898222e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7005000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      288    3.3898222e+04   0.000000e+00   1.700500e+00      0s
#      298    3.3898222e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 298 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.389822250e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xfa8b82bc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.492200e+04   0.000000e+00      0s
#      280    3.3812207e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.3570000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      283    3.3812207e+04   0.000000e+00   1.357000e+00      0s
#      291    3.3812207e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 291 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.381220700e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xd48fd9a2
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.603100e+04   0.000000e+00      0s
#      293    3.3942256e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.8595000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      296    3.3942256e+04   0.000000e+00   1.859500e+00      0s
#      306    3.3942256e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 306 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.394225650e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x7d20d2c7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.451500e+04   0.000000e+00      0s
#      276    3.3937376e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.8680000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      279    3.3937376e+04   0.000000e+00   1.868000e+00      0s
#      289    3.3937376e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 289 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.393737650e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x8c9b9f78
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.467800e+04   0.000000e+00      0s
#      279    3.3851809e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7090000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      282    3.3851809e+04   0.000000e+00   1.709000e+00      0s
#      291    3.3851809e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 291 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.385180950e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xd0764079
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.357200e+04   0.000000e+00      0s
#      263    3.3927315e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.5465000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      266    3.3927315e+04   0.000000e+00   2.546500e+00      0s
#      280    3.3927315e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 280 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.392731550e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x9fa21077
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.545800e+04   0.000000e+00      0s
#      287    3.3823889e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.3400000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      290    3.3823889e+04   0.000000e+00   1.340000e+00      0s
#      298    3.3823889e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 298 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.382388900e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xe9346067
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.458100e+04   0.000000e+00      0s
#      278    3.3863122e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.1895000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      281    3.3863122e+04   0.000000e+00   1.189500e+00      0s
#      288    3.3863122e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 288 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.386312250e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xec98c460
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.495900e+04   0.000000e+00      0s
#      282    3.3890646e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.2285000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      285    3.3890645e+04   0.000000e+00   2.228500e+00      0s
#      297    3.3890645e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 297 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.389064550e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x97684d43
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.360600e+04   0.000000e+00      0s
#      268    3.3897950e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7005000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      271    3.3897950e+04   0.000000e+00   1.700500e+00      0s
#      281    3.3897950e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 281 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.389795000e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x4f7fb279
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.483900e+04   0.000000e+00      0s
#      280    3.3874461e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.3790000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      283    3.3874461e+04   0.000000e+00   2.379000e+00      0s
#      295    3.3874461e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 295 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.387446100e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xa6cc16af
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.508300e+04   0.000000e+00      0s
#      280    3.3874276e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.2200000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      283    3.3874276e+04   0.000000e+00   2.220000e+00      0s
#      295    3.3874276e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 295 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.387427650e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x665ddf28
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.467600e+04   0.000000e+00      0s
#      277    3.3832374e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7005000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      280    3.3832374e+04   0.000000e+00   1.700500e+00      0s
#      290    3.3832374e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 290 iterations and 0.02 seconds (0.01 work units)
# Optimal objective  3.383237450e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xe5f90535
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.460600e+04   0.000000e+00      0s
#      275    3.3902972e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.3570000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      278    3.3902972e+04   0.000000e+00   1.357000e+00      0s
#      285    3.3902972e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 285 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.390297200e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x55f36a71
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.472800e+04   0.000000e+00      0s
#      279    3.3891659e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.5330000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      282    3.3891659e+04   0.000000e+00   1.533000e+00      0s
#      290    3.3891659e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 290 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.389165900e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x0b10b294
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.535000e+04   0.000000e+00      0s
#      286    3.3891579e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.3655000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      289    3.3891579e+04   0.000000e+00   1.365500e+00      0s
#      297    3.3891579e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 297 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.389157950e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x50c51144
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.536800e+04   0.000000e+00      0s
#      283    3.3940195e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.5415000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      286    3.3940195e+04   0.000000e+00   1.541500e+00      0s
#      295    3.3940195e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 295 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.394019550e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0xd1b70c85
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.502500e+04   0.000000e+00      0s
#      278    3.3823185e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.2115000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      281    3.3823185e+04   0.000000e+00   2.211500e+00      0s
#      292    3.3823185e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 292 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.382318500e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x0b3a6103
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.505500e+04   0.000000e+00      0s
#      279    3.3941552e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7005000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      282    3.3941552e+04   0.000000e+00   1.700500e+00      0s
#      292    3.3941552e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 292 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.394155250e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x9abf412a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.546200e+04   0.000000e+00      0s
#      286    3.3988669e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7090000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      289    3.3988669e+04   0.000000e+00   1.709000e+00      0s
#      298    3.3988669e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 298 iterations and 0.02 seconds (0.01 work units)
# Optimal objective  3.398866950e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x642f0f14
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.535000e+04   0.000000e+00      0s
#      284    3.3876505e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.6750000e-01      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      287    3.3876505e+04   0.000000e+00   1.675000e-01      0s
#      288    3.3876505e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 288 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.387650500e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x533ce51c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.512800e+04   0.000000e+00      0s
#      284    3.3873967e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.5550000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      287    3.3873967e+04   0.000000e+00   2.555000e+00      0s
#      301    3.3873967e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 301 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.387396700e+04
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3000 rows, 3015 columns and 6000 nonzeros
# Model fingerprint: 0x3e946310
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 1e+02]
# Presolve time: 0.00s
# Presolved: 3000 rows, 3015 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.449100e+04   0.000000e+00      0s
#      274    3.3863114e+04   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.1980000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      277    3.3863114e+04   0.000000e+00   1.198000e+00      0s
#      284    3.3863114e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 284 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.386311400e+04
# The average cost associated with the optimal plan over 50 trials is: 33895.15497999977
