# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('/Users/mahinbindra/Downloads/sales_data.csv')

# %%
df.head()
# Out:
#       Product    Region   Price  Units Sold   Sale Date
# 0         NaN  Region_6   75.96        10.0  2022-01-01
# 1         NaN  Region_1  175.78         8.0  2022-01-02
# 2  Product_46  Region_3   20.43        12.0  2022-01-03
# 3  Product_36  Region_1   12.77        10.0  2022-01-04
# 4  Product_17  Region_6  125.69         6.0  2022-01-05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      946 non-null    object
#  2   Price       945 non-null    float64
#  3   Units Sold  946 non-null    float64
#  4   Sale Date   1050 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 41.1+ KB

# %%
df.describe(include = 'all')
# Out:
#            Product    Region        Price  Units Sold   Sale Date
# count          947       946   945.000000  946.000000        1050
# unique          50        10          NaN         NaN        1000
# top     Product_45  Region_9          NaN         NaN  2022-07-28
# freq            28       109          NaN         NaN           2
# mean           NaN       NaN   107.598688   10.048626         NaN
# std            NaN       NaN   124.020322    3.172261         NaN
# min            NaN       NaN     0.200000    2.000000         NaN
# 25%            NaN       NaN    29.430000    8.000000         NaN
# 50%            NaN       NaN    78.130000   10.000000         NaN
# 75%            NaN       NaN   142.570000   12.000000         NaN
# max            NaN       NaN  2143.300000   22.000000         NaN

# %%
df[df['Product'].isnull() & df['Region'].isnull() & df['Price'].isnull() & df['Units Sold'].isnull()]
# Out:
#     Product Region  Price  Units Sold   Sale Date
# 272     NaN    NaN    NaN         NaN  2022-09-30

# %%
df.drop(272, axis = 0, inplace = True)

# %%
df[df['Product'].isnull() & df['Region'].isnull() & df['Price'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Product, Region, Price, Units Sold, Sale Date]
# Index: []

# %%
df[df['Product'].isnull() & df['Region'].isnull() & df['Units Sold'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Product, Region, Price, Units Sold, Sale Date]
# Index: []

# %%
df[df['Product'].isnull() & df['Region'].isnull()]
# Out:
#     Product Region   Price  Units Sold   Sale Date
# 18      NaN    NaN  276.27         9.0  2022-01-19
# 21      NaN    NaN   46.10        14.0  2022-01-22
# 57      NaN    NaN   30.71        12.0  2022-02-27
# 184     NaN    NaN  117.23         8.0  2022-07-04
# 203     NaN    NaN  134.49        13.0  2022-07-23
# 317     NaN    NaN   39.33        12.0  2022-11-14
# 629     NaN    NaN  151.72        11.0  2023-09-22
# 677     NaN    NaN  162.27         6.0  2023-11-09
# 786     NaN    NaN  249.05         6.0  2024-02-26

# %%
df.drop(df[df['Product'].isnull() & df['Region'].isnull()].index, axis=0, inplace=True)

# %%
df.describe (include = 'all')
# Out:
#            Product    Region        Price  Units Sold   Sale Date
# count          947       946   936.000000  937.000000        1040
# unique          50        10          NaN         NaN         990
# top     Product_45  Region_9          NaN         NaN  2022-05-17
# freq            28       109          NaN         NaN           2
# mean           NaN       NaN   107.343579   10.048026         NaN
# std            NaN       NaN   124.320943    3.175568         NaN
# min            NaN       NaN     0.200000    2.000000         NaN
# 25%            NaN       NaN    29.285000    8.000000         NaN
# 50%            NaN       NaN    77.520000   10.000000         NaN
# 75%            NaN       NaN   141.912500   12.000000         NaN
# max            NaN       NaN  2143.300000   22.000000         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1040 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      946 non-null    object
#  2   Price       936 non-null    float64
#  3   Units Sold  937 non-null    float64
#  4   Sale Date   1040 non-null   object
# dtypes: float64(2), object(3)
# memory usage:
# Region_10   460.20       98.0  10.163265  2.895763  4.0  8.0  10.0  13.00
# Region_2    623.60       78.0   9.884615  3.353543  2.0  8.0  10.0  12.00
# Region_3    665.00       88.0  10.227273  3.479752  2.0  8.0  10.0  12.00
# Region_4    505.01       95.0   9.884211  3.367123  4.0  8.0   9.0  11.50
# Region_5    487.81       84.0  10.095238  3.236163  2.0  8.0  10.0  12.00
# Region_6    510.06       85.0  10.117647  3.021399  3.0  8.0  10.0  12.00
# Region_7    517.29       68.0   9.823529  3.190196  3.0  7.0   9.0  12.00
# Region_8   2143.30       83.0   9.819277  2.992448  4.0  7.0  10.0  12.00
# Region_9    496.61       97.0  10.195876  3.248843  3.0  8.0  10.0  12.00
#
#
#             max
# Region
# Other      16.0
# Region_1   18.0
# Region_10  16.0
# Region_2   18.0
# Region_3   19.0
# Region_4   22.0
# Region_5   20.0
# Region_6   18.0
# Region_7   19.0
# Region_8   19.0
# Region_9   17.0

# %%
df_test_2 = df.copy()

# %%
df_test_2['Region'] = df_test_2['Region'].fillna('Region_5')

# %%
df_test_2.groupby('Region').describe()
# Out:
#            Price
#            count        mean         std   min      25%     50%       75%
# Region
# Region_1    77.0  102.055844  119.538086  0.96  26.0900  76.660  117.3300  \
# Region_10   98.0  101.472959   95.235575  5.48  33.8825  76.915  134.7500
# Region_2    76.0  125.228421  121.794759  0.58  29.2025  94.490  201.7300
# Region_3    82.0   97.719878   98.490504  1.29  26.8525  78.050  132.7475
# Region_4    88.0  106.825568  101.862712  0.20  31.3950  83.510  141.7850
# Region_5   173.0  106.300347  100.996021  0.31  37.0100  77.220  148.9900
# Region_6    81.0   81.150000   91.474345  0.54  27.9400  50.880   97.3000
# Region_7    70.0   92.043714   91.539662  0.61  23.9350  70.250  118.9775
# Region_8    85.0  156.836941  256.273082  0.61  37.7000  92.700  192.9100
# Region_9   106.0  103.798019   89.781121  0.33  30.3775  90.215  141.2050
#
#                    Units Sold
#                max      count       mean       std  min  25%   50%    75%
# Region
# Region_1    713.29       80.0  10.150000  3.460811  2.0  8.0  10.0  12.25  \
# Region_10   460.20       98.0  10.163265  2.895763  4.0  8.0  10.0  13.00
# Region_2    623.60       78.0   9.884615  3.353543  2.0  8.0  10.0  12.00
# Region_3    665.00       88.0  10.227273  3.479752  2.0  8.0  10.0  12.00
# Region_4    505.01       95.0   9.884211  3.367123  4.0  8.0   9.0  11.50
# Region_5    605.87      165.0  10.090909  3.001663  2.0  8.0  10.0  12.00
# Region_6    510.06       85.0  10.117647  3.021399  3.0  8.0  10.0  12.00
# Region_7    517.29       68.0   9.823529  3.190196  3.0  7.0   9.0  12.00
# Region_8   2143.30       83.0   9.819277  2.992448  4.0  7.0  10.0  12.00
# Region_9    496.61       97.0  10.195876  3.248843  3.0  8.0  10.0  12.00
#
#
#             max
# Region
# Region_1   18.0
# Region_10  16.0
# Region_2   18.0
# Region_3   19.0
# Region_4   22.0
# Region_5   20.0
# Region_6   18.0
# Region_7   19.0
# Region_8   19.0
# Region_9   17.0

# %%
df['Region'] = df['Region'].fillna('Other')

# %%
df_test['Product'] = df_test['Product'].fillna('Other')

# %%
df_test.groupby('Product').describe(include='all')
# Out:
#            Region                                                       ...
#             count unique        top freq mean  std  min  25%  50%  75%  ...
# Product                                                                 ...
# Other          93     10  Region_10   14  NaN  NaN  NaN  NaN  NaN  NaN  ...  \
# Product_1      26     10      Other    6  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Product
NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [50 rows x 44 columns]

# %%
df_test_2.groupby('Product').describe(include='all').loc['Product_45']
# Out:
# Region      count            121
#             unique            10
#             top        Region_10
#             freq              18
#             mean             NaN
#             std              NaN
#             min              NaN
#             25%              NaN
#             50%              NaN
#             75%              NaN
#             max              NaN
# Price       count          109.0
#             unique           NaN
#             top              NaN
#             freq             NaN
#             mean      102.673945
#             std       101.301569
#             min             0.58
#             25%            28.27
#             50%            78.69
#             75%           134.96
#             max            580.6
# Units Sold  count          106.0
#             unique           NaN
#             top              NaN
#             freq             NaN
#             mean        9.443396
#             std         2.898539
#             min              3.0
#             25%              7.0
#             50%              9.0
#             75%             11.0
#             max             16.0
# Sale Date   count            121
#             unique           115
#             top       2023-07-21
#             freq               2
#             mean             NaN
#             std              NaN
#             min              NaN
#             25%              NaN
#             50%              NaN
#             75%              NaN
#             max              NaN
# Name: Product_45, dtype: object

# %%
df_test_3= df.copy()

# %%
product_list = df['Product'].unique()
product_list
# Out:
# array([nan, 'Product_46', 'Product_36', 'Product_17', 'Product_45',
#        'Product_31', 'Product_18', 'Product_16', 'Product_9',
#        'Product_20', 'Product_1', 'Product_2', 'Product_3', 'Product_43',
#        'Product_33', 'Product_14', 'Product_50', 'Product_6',
#        'Product_13', 'Product_11', 'Product_27', 'Product_28',
#        'Product_24', 'Product_34', 'Product_25', 'Product_4',
#        'Product_35', 'Product_48', 'Product_10', 'Product_49',
#        'Product_12', 'Product_42', 'Product_5', 'Product_37',
#        'Product_26', 'Product_8', 'Product_22', 'Product_32',
#        'Product_23', 'Product_15', 'Product_29', 'Product_44',
#        'Product_47', 'Product_41', 'Product_39', 'Product_40',
#        'Product_30', 'Product_7', 'Product_21', 'Product_38',
#        'Product_19'], dtype=object)

# %%
product_list[1:]
# Out:
# array(['Product_46', 'Product_36', 'Product_17', 'Product_45',
#        'Product_31', 'Product_18', 'Product_16', 'Product_9',
#        'Product_20', 'Product_1', 'Product_2', 'Product_3', 'Product_43',
#        'Product_33', 'Product_14', 'Product_50', 'Product_6',
#        'Product_13', 'Product_11', 'Product_27', 'Product_28',
#        'Product_24', 'Product_34', 'Product_25', 'Product_4',
#        'Product_35', 'Product_48', 'Product_10', 'Product_49',
#        'Product_12', 'Product_42', 'Product_5', 'Product_37',
#        'Product_26', 'Product_8', 'Product_22', 'Product_32',
#        'Product_23', 'Product_15', 'Product_29', 'Product_44',
#        'Product_47', 'Product_41', 'Product_39', 'Product_40',
#        'Product_30', 'Product_7', 'Product_21', 'Product_38',
#        'Product_19'], dtype=object)

# %%
missing_data = df_test_3['Product'].isnull().sum()
missing_data
# Out:
# 93

# %%
random_products = np.random.choice(product_list, size = missing_data)
random_products
# Out:
# array(['Product_24', 'Product_18', 'Product_23', 'Product_18',
#        'Product_34', 'Product_23', 'Product_10', 'Product_27',
#        'Product_15', 'Product_27', 'Product_24', 'Product_7',
#        'Product_50', 'Product_27', 'Product_2', 'Product_7', 'Product_39',
#        'Product_1', 'Product_10', 'Product_37', 'Product_5', 'Product_26',
#        'Product_29', 'Product_6', 'Product_31', 'Product_19',
#        'Product_11', 'Product_29', 'Product_22', 'Product_45',
#        'Product_50', 'Product_1', 'Product_32', 'Product_49',
#        'Product_35', 'Product_49', 'Product_15', 'Product_16',
#        'Product_17', 'Product_10', 'Product_24', 'Product_17',
#        'Product_15', 'Product_2', 'Product_41', 'Product_2', 'Product_50',
#        'Product_43', 'Product_36', 'Product_43', 'Product_5',
#        'Product_31', 'Product_43', 'Product_3', 'Product_44',
#        'Product_34', 'Product_12', 'Product_14', 'Product_28',
#        'Product_34', 'Product_27', 'Product_48', 'Product_14',
#        'Product_15', 'Product_15', 'Product_9', 'Product_13', 'Product_1',
#        'Product_20', 'Product_2', 'Product_46', 'Product_4', 'Product_2',
#        'Product_14', 'Product_18', 'Product_19', 'Product_26',
#        'Product_35', 'Product_32', 'Product_5', 'Product_36',
#        'Product_45', 'Product_14', 'Product_50', 'Product_34',
#        'Product_12', 'Product_1', 'Product_4', 'Product_47', 'Product_28',
#        'Product_48', 'Product_20', 'Product_30'], dtype=object)

# %%
df_test_3.loc[df_test_3['Product'].isnull(), 'Product'] = random_products

# %%
df_test_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1040 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     1040 non-null   object
#  1   Region      1040 non-null   object
#  2   Price       936 non-null    float64
#  3   Units Sold  937 non-null    float64
#  4   Sale Date   1040 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 48.8+ KB

# %%
df_test_3.groupby('Product').describe().describe()
# Out:
#            Price
#            count        mean         std        min        25%        50%
# count  50.000000   50.000000   50.000000  50.000000  50.000000   50.00000  \
# mean   18.720000  106.779420  105.815772   5.606200  34.839750   77.08590
# std     4.356745   30.227352   61.083324   5.546087  14.959783   24.20091
# min     9.000000   55.105455   52.545663   0.200000  11.205000   18.67000
# 25%    16.000000   84.651701   72.100141   1.382500  24.750625   60.55750
# 50%    18.000000  104.973205   94.888710   4.365000  31.276250   77.98750
# 75%    22.000000  126.381667  116.666265   7.295000  42.835000   90.13375
# max    30.000000  204.806429  461.307644  24.240000  75.930000  149.51000
#
#                                Units Sold
#               75%          max      count       mean        std        min
# count   50.000000    50.000000  50.000000  50.000000  50.000000  50.000000  \
# mean   141.507850   389.434800  18.740000  10.071862   3.093922   4.600000
# std     41.560692   284.841833   4.265715   0.768309   0.638457   1.498298
# min     68.330000   169.510000  11.000000   8.333333   1.300350   2.000000
# 25%    108.565625   264.217500  15.250000   9.631313   2.680583   4.000000
# 50%    132.598750   313.640000  19.500000  10.051587   3.004474   4.500000
# 75%    178.167500   431.382500  22.000000  10.687500   3.498585   6.000000
# max    251.460000  2143.300000  27.000000  11.583333   4.235317   8.000000
#
#
#              25%        50%        75%        max
# count  50.000000  50.000000  50.000000  50.000000
# mean    8.075000   9.890000  12.055000  16.020000
# std     0.916473   0.991237   1.275045   2.035301
# min     5.750000   8.000000   9.750000  11.000000
# 25%     7.250000   9.000000  11.000000  15.000000
# 50%     8.000000  10.000000  12.000000  16.000000
# 75%     9.000000  10.500000  13.000000  17.000000
# max    10.000000  13.000000  14.500000  22.000000

# %%
df.groupby('Product').describe().describe()
# Out:
#            Price
#            count        mean         std        min        25%         50%
# count  50.000000   50.000000   50.000000  50.000000  50.000000   50.000000  \
# mean   17.080000  108.080746  107.268490   5.960400  36.068650   77.502500
# std     4.217747   34.519977   70.546457   5.645199  14.890622   25.706923
# min     8.000000   59.752000   47.375192   0.200000  12.860000   23.145000
# 25%    14.000000   83.218514   71.576201   1.382500  25.575625   57.622500
# 50%    16.000000  100.605217   93.842105   4.730000  33.072500   78.342500
# 75%    19.750000  126.828421  118.506089   7.735000  43.616875   93.935000
# max    27.000000  224.842500  528.447195  24.240000  72.180000  149.510000
#
#                                Units Sold
#               75%          max      count       mean        std        min
# count   50.000000    50.000000  50.000000  50.000000  50.000000  50.000000  \
# mean   144.340800   385.134000  17.040000  10.119407   3.110291   4.740000
# std     52.554858   286.899148   3.999796   0.801584   0.676133   1.562442
# min     72.410000   169.510000  10.000000   8.411765   1.300350   2.000000
# 25%    104.546875   253.000000  14.000000   9.566986   2.671440   4.000000
# 50%    132.377500   307.430000  17.000000  10.129555   3.003910   5.000000
# 75%    179.340000   431.382500  20.000000  10.702489   3.621929   6.000000
# max    353.037500  2143.300000  26.000000  11.636364   4.323518   8.000000
#
#
#              25%        50%       75%        max
# count  50.000000  50.000000  50.00000  50.000000
# mean    8.180000   9.920000  12.15500  16.000000
# std     0.950349   0.927802   1.36734   2.070197
# min     5.750000   8.000000  10.00000  11.000000
# 25%     7.500000   9.000000  11.00000  15.000000
# 50%     8.000000  10.000000  12.00000  16.000000
# 75%     9.000000  10.500000  13.00000  17.000000
# max    10.000000  12.000000  15.00000  22.000000

# %%
df.dropna(subset = ['Product'], axis = 0, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 947 entries, 2 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      947 non-null    object
#  2   Price       854 non-null    float64
#  3   Units Sold  852 non-null    float64
#  4   Sale Date   947 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 44.4+ KB

# %%
df_test = df.copy()
df_test_2 = df.copy()
df_test_3 = df.copy()

# %%
df_test['Price'] = df_test['Price'].fillna(df_test['Price'].median())

# %%
df_test_2['Price'] = df_test_2['Price'].fillna(df_test_2.groupby('Product')['Price'].transform('median'))

# %%
df_test_3['Price'] = df_test_3['Price'].fillna(df_test_3.groupby('Region')['Price'].transform('median'))

# %%
df_test.describe()
# Out:
#              Price  Units Sold
# count   947.000000  852.000000
# mean    104.990517   10.090376
# std     120.857982    3.192611
# min       0.200000    2.000000
# 25%      34.165000    8.000000
# 50%      77.520000   10.000000
# 75%     132.285000   12.000000
# max    2143.300000   22.000000

# %%
df_test_2.describe()
# Out:
#              Price  Units Sold
# count   947.000000  852.000000
# mean    105.009050   10.090376
# std     121.081348    3.192611
# min       0.200000    2.000000
# 25%      33.820000    8.000000
# 50%      78.600000   10.000000
# 75%     133.250000   12.000000
# max    2143.300000   22.000000

# %%
df_test_3.describe()
# Out:
#              Price  Units Sold
# count   947.000000  852.000000
# mean    104.867645   10.090376
# std     120.938571    3.192611
# min       0.200000    2.000000
# 25%      34.165000    8.000000
# 50%      77.965000   10.000000
# 75%     132.285000   12.000000
# max    2143.300000   22.000000

# %%
df.describe()
# Out:
#              Price  Units Sold
# count   854.000000  852.000000
# mean    107.982037   10.090376
# std     126.917044    3.192611
# min       0.200000    2.000000
# 25%      29.462500    8.000000
# 50%      77.520000   10.000000
# 75%     142.512500   12.000000
# max    2143.300000   22.000000

# %%
df['Price'] = df['Price'].fillna(df['Price'].mean())

# %%
df_test = df.copy()
df_test_2 = df.copy()
df_test_3 = df.copy()

# %%
df_test['Units Sold'] = df_test['Units Sold'].fillna(df_test['Units Sold'].median())

# %%
df_test_2['Units Sold'] = df_test_2['Units Sold'].fillna(df_test_2.groupby('Product')['Units Sold'].transform('median'))

# %%
df_test_3['Units Sold'] = df_test_3['Units Sold'].fillna(df_test_3.groupby('Region')['Units Sold'].transform('median'))

# %%
df_test.describe()
# Out:
#              Price  Units Sold
# count   947.000000  947.000000
# mean    107.982037   10.081309
# std     120.517162    3.028187
# min       0.200000    2.000000
# 25%      34.165000    8.000000
# 50%      87.630000   10.000000
# 75%     132.285000   12.000000
# max    2143.300000   22.000000

# %%
df_test_2.describe()
# Out:
#              Price  Units Sold
# count   947.000000  947.000000
# mean    107.982037   10.056494
# std     120.517162    3.045675
# min       0.200000    2.000000
# 25%      34.165000    8.000000
# 50%      87.630000   10.000000
# 75%     132.285000   12.000000
# max    2143.300000   22.000000

# %%
df_test_3.describe()
# Out:
#              Price  Units Sold
# count   947.000000  947.000000
# mean    107.982037   10.070750
# std     120.517162    3.030197
# min       0.200000    2.000000
# 25%      34.165000    8.000000
# 50%      87.630000   10.000000
# 75%     132.285000   12.000000
# max    2143.300000   22.000000

# %%
df.describe()
# Out:
#              Price  Units Sold
# count   947.000000  852.000000
# mean    107.982037   10.090376
# std     120.517162    3.192611
# min       0.200000    2.000000
# 25%      34.165000    8.000000
# 50%      87.630000   10.000000
# 75%     132.285000   12.000000
# max    2143.300000   22.000000

# %%
df['Units Sold'] = df['Units Sold'].fillna(df['Units Sold'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 947 entries, 2 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      947 non-null    object
#  2   Price       947 non-null    float64
#  3   Units Sold  947 non-null    float64
#  4   Sale Date   947 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 44.4+ KB

# %%
df.describe(include='all')
# Out:
#            Product    Region        Price  Units Sold   Sale Date
# count          947       947   947.000000  947.000000         947
# unique          50        11          NaN         NaN         900
# top     Product_45  Region_9          NaN         NaN  2023-04-15
# freq            28       101          NaN         NaN           2
# mean           NaN       NaN   107.982037   10.090376         NaN
# std            NaN       NaN   120.517162    3.028065         NaN
# min            NaN       NaN     0.200000    2.000000         NaN
# 25%            NaN       NaN    34.165000    8.000000         NaN
# 50%            NaN       NaN    87.630000   10.000000         NaN
# 75%            NaN       NaN   132.285000   12.000000         NaN
# max            NaN       NaN  2143.300000   22.000000         NaN

# %%
df['Sale Date'] = pd.to_datetime(df['Sale Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 947 entries, 2 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      947 non-null    object
#  2   Price       947 non-null    float64
#  3   Units Sold  947 non-null    float64
#  4   Sale Date   947 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 44.4+ KB

# %%
sns.boxplot(data = df, y = 'Price')
# Out:
# <Axes: ylabel='Price'>

# %%
drop_price_outliers = df[df['Price']>1000].index
drop_price_outliers
# Out:
# Index([969], dtype='int64')

# %%
df.drop(drop_price_outliers, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 946 entries, 2 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     946 non-null    object
#  1   Region      946 non-null    object
#  2   Price       946 non-null    float64
#  3   Units Sold  946 non-null    float64
#  4   Sale Date   946 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 44.3+ KB

# %%
sns.boxplot(data = df, y = 'Units Sold')
# Out:
# <Axes: ylabel='Units Sold'>

# %%
df['Units Sold'].sort_values(ascending=False).head(10)
# Out:
# 719     22.0
# 221     20.0
# 232     19.0
# 962     19.0
# 912     19.0
# 167     18.0
# 796     18.0
# 678     18.0
# 1006    18.0
# 390     18.0
# Name: Units Sold, dtype: float64

# %%
drop_units_outliers = df[df['Units Sold']>18].index
drop_units_outliers
# Out:
# Index([221, 232, 719, 912, 962], dtype='int64')

# %%
df.drop(drop_units_outliers, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 941 entries, 2 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     941 non-null    object
#  1   Region      941 non-null    object
#  2   Price       941 non-null    float64
#  3   Units Sold  941 non-null    float64
#  4   Sale Date   941 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 44.1+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 894 entries, 2 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     894 non-null    object
#  1   Region      894 non-null    object
#  2   Price       894 non-null    float64
#  3   Units Sold  894 non-null    float64
#  4   Sale Date   894 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 41.9+ KB

# %%
sns.histplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
from scipy import stats
print(stats.skew(df['Price']))
# Out:
# 2.138524034009571

# %%
sns.histplot(df['Units Sold'])
# Out:
# <Axes: xlabel='Units Sold', ylabel='Count'>

# %%
print(stats.skew(df['Units Sold']))
print(stats.kurtosis(df['Units Sold']))
# Out:
# 0.11499812017104176
# 0.1125839391233936

# %%
df.groupby('Product')['Units Sold'].count().sort_values(ascending=True).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
df.groupby('Region')['Units Sold'].count().sort_values(ascending=True).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Region'>

# %%
units_by_region = df.groupby('Region')['Units Sold'].aggregate(['sum', 'mean', 'median', 'count'])
units_by_region
# Out:
#                   sum       mean     median  count
# Region
# Other      907.084507  10.078717  10.045188     90
# Region_1   745.451878  10.211670  10.000000     73
# Region_10  905.723005  10.063589  10.000000     90
# Region_2   724.361502  10.202275  10.000000     71
# Region_3   788.632629  10.110675  10.090376     78
# Region_4   883.451878   9.708262  10.000000     91
# Region_5   830.903756  10.010889  10.000000     83
# Region_6   770.723005  10.141092  10.000000     76
# Region_7   618.903756   9.823869  10.090376     63
# Region_8   830.174883  10.002107  10.090376     83
# Region_9   980.813380  10.216806  10.000000     96

# %%
units_by_region['sum'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
units_by_region['mean'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
units_by_region['median'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
units_by_region['count'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
units_by_product = df.groupby('Product')['Units Sold'].aggregate(['sum', 'mean', 'median', 'count'])
units_by_product
# Out:
#                    sum       mean     median  count
# Product
# Product_1   238.090376   9.920432   9.000000     24
# Product_10  179.090376  11.193148  10.545188     16
# Product_11  153.361502  10.954393  10.090376     14
# Product_12  139.000000  10.692308  11.000000     13
# Product_13  234.180751  10.181772  10.000000     23
# Product_14  183.180751  10.176708  10.045188     18
# Product_15  197.180751  10.954486  11.000000     18
# Product_16  185.000000  10.277778  11.000000     18
# Product_17  177.090376   9.838354   9.500000     18
# Product_18  142.271127  10.162223  10.090376     14
# Product_19  200.000000  10.000000  10.000000     20
# Product_2   201.180751  10.588461  10.000000     19
# Product_20  153.180751  10.212050  10.000000     15
# Product_21  168.271127  11.218075  10.090376     15
# Product_22  129.271127   9.233652   9.000000     14
# Product_23  216.180751  10.294321  10.090376     21
# Product_24  163.180751  10.198797  10.000000     16
# Product_25  160.090376   9.417081   9.000000     17
# Product_26  119.000000   9.916667   9.500000     12
# Product_27  172.180751  10.761297  10.545188     16
# Product_28  166.090376  10.380648   9.000000     16
# Product_29  196.271127   9.813556  10.045188     20
# Product_3   128.000000  11.636364  12.000000     11
# Product_30  247.451878  10.758777  10.090376     23
# Product_31  209.000000   9.952381  11.000000     21
# Product_32  145.000000   9.062500   8.000000     16
# Product_33  247.090376   9.151495  10.000000     27
# Product_34  174.090376  10.240610  10.000000     17
# Product_35  186.090376   9.794230  10.000000     19
# Product_36  117.180751   9.013904  10.000000     13
# Product_37  183.090376   9.636336  10.000000     19
# Product_38  122.271127   9.405471  10.000000     13
# Product_39  153.180751   8.510042   9.000000     18
# Product_4   243.090376  10.569147  10.090376     23
# Product_40  184.180751   9.209038   9.500000     20
# Product_41  176.000000  10.352941  10.000000     17
# Product_42  181.361502   9.545342   8.000000     19
# Product_43  245.090376  10.656103  11.000000     23
# Product_44  173.271127   9.626174   9.500000     18
# Product_45  228.632629   9.145305  10.000000     25
# Product_46  187.090376   9.846862  10.000000     19
# Product_47  125.180751   9.629289  10.000000     13
# Product_48  218.000000  10.900000  11.000000     20
# Product_49  127.000000   9.769231  10.000000     13
# Product_5   240.542254   8.908972  10.000000     27
# Product_50  219.180751  10.959038  11.000000     20
# Product_6   148.271127   8.721831   9.000000     17
# Product_7   187.180751  11.010632  10.090376     17
# Product_8   153.180751  10.941482  10.545188     14
# Product_9   163.180751  10.878717  10.000000     15

# %%
units_by_product['sum'].sort_values(ascending=False).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
units_by_product['mean'].sort_values(ascending=False).plot(kind='bar', figsize=(10,6))
# Out:
# <Axes: xlabel='Product'>

# %%
df.groupby('Product')['Price'].mean().sort_values(ascending=False).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
sns.lmplot(x = 'Price', y = 'Units Sold', data = df)

# %%
df['Revenue'] = df['Price'] * df['Units Sold']

# %%
df
# Out:
#         Product     Region   Price  Units Sold  Sale Date  Revenue
# 2    Product_46   Region_3   20.43        12.0 2022-01-03   245.16
# 3    Product_36   Region_1   12.77        10.0 2022-01-04   127.70
# 4    Product_17   Region_6  125.69         6.0 2022-01-05   754.14
# 5    Product_45   Region_1    8.63        11.0 2022-01-06    94.93
# 6    Product_31   Region_3   23.73         6.0 2022-01-07   142.38
# ..          ...        ...     ...         ...        ...      ...
# 993   Product_7   Region_9  128.51        17.0 2024-09-20  2184.67
# 994   Product_1   Region_4   95.24         7.0 2024-09-21   666.68
# 996  Product_36      Other   46.19         9.0 2024-09-23   415.71
# 998   Product_2  Region_10   43.44        15.0 2024-09-25   651.60
# 999  Product_35   Region_8   56.95         6.0 2024-09-26   341.70
#
# [894 rows x 6 columns]

# %%
region_1 = df[df['Region'] == 'Region_1'].groupby('Product').aggregate({'Price' : 'mean', 'Units Sold' : ['sum', 'mean'], 'Revenue' : ['sum', 'mean']})
region_1['Price'].sort_values('mean', ascending=False).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
region_1['Units Sold']['sum'].sort_values(ascending=False).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
region_1['Revenue']['sum'].sort_values(ascending=False).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Product'>

# %%
region_4 = df[df['Region'] == 'Region_4'].groupby('Product').aggregate({'Price' : 'mean', 'Units Sold' : ['sum', 'mean'], 'Revenue' : ['sum', 'mean']})

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (20,5))

region_4['Revenue']['sum'].sort_values(ascending=False).plot(kind='bar', ax=ax1, title='Revenue')
region_4['Units Sold']['sum'].sort_values(ascending=False).plot(kind='bar', ax=ax2, title='Volume')
# Out:
# <Axes: title={'center': 'Volume'}, xlabel='Product'>
