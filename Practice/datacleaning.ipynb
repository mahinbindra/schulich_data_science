# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/mahinbindra/Downloads/messy_data (2).csv')

# %%
df
# Out:
#      Age       Income  Gender Product  Quantity
# 0     56  59544.57663  Female       D         3
# 1     46  36399.18997  Female     NaN         1
# 2     32  57140.63881  Female       D         2
# 3     60  69554.91903    Male       C         5
# 4     25  53173.80518  Female       D         2
# ..   ...          ...     ...     ...       ...
# 100   61  37341.55459    Male       D         5
# 101   55  35516.63492  Female       A         3
# 102   31  53254.05089    Male       B         2
# 103   21          NaN    Male       B         2
# 104   60  69554.91903    Male       C         5
#
# [105 rows x 5 columns]

# %%
df.describe(include = 'all')
# Out:
#                Age         Income  Gender Product   Quantity
# count   105.000000      94.000000     105     100  105.00000
# unique         NaN            NaN       2       4        NaN
# top            NaN            NaN  Female       D        NaN
# freq           NaN            NaN      58      28        NaN
# mean     42.076190   52867.862808     NaN     NaN    3.20000
# std      15.940813   29896.579420     NaN     NaN    1.44382
# min      18.000000   20901.331720     NaN     NaN    1.00000
# 25%      31.000000   37814.315255     NaN     NaN    2.00000
# 50%      41.000000   48760.369705     NaN     NaN    3.00000
# 75%      55.000000   61644.277868     NaN     NaN    5.00000
# max     120.000000  300000.000000     NaN     NaN    5.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       105 non-null    int64
#  1   Income    94 non-null     float64
#  2   Gender    105 non-null    object
#  3   Product   100 non-null    object
#  4   Quantity  105 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.2+ KB

# %%
df.loc[df['Product'].isnull()]
# Out:
#     Age       Income  Gender Product  Quantity
# 1    46  36399.18997  Female     NaN         1
# 34   64  40845.16974  Female     NaN         2
# 45   31  30330.13661    Male     NaN         5
# 86   43  63312.67422  Female     NaN         4
# 94   42  67538.11470    Male     NaN         1

# %%
df.drop_duplicates(inplace = True)

# %%
df2 = df.dropna(subset = ['Product'])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       95 non-null     int64
#  1   Income    85 non-null     float64
#  2   Gender    95 non-null     object
#  3   Product   95 non-null     object
#  4   Quantity  95 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.5+ KB

# %%
import seaborn as sns

# %%
sns.scatterplot(x = 'Gender', y = 'Income', data = df2)
# Out:
# <Axes: xlabel='Gender', ylabel='Income'>

# %%
df2[df2['Income']>250000]
# Out:
#     Age    Income Gender Product  Quantity
# 99   61  300000.0   Male       B         4

# %%
df2.drop(99, axis = 0, inplace = True)
# Out:
# /var/folders/ht/6xpr92fx6hb_qsdf6ml3w35w0000gn/T/ipykernel_3772/2835192896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(99, axis = 0, inplace = True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 94 entries, 0 to 98
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       94 non-null     int64
#  1   Income    84 non-null     float64
#  2   Gender    94 non-null     object
#  3   Product   94 non-null     object
#  4   Quantity  94 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.4+ KB

# %%
sns.scatterplot(x = 'Product', y = 'Quantity', data = df2)
# Out:
# <Axes: xlabel='Product', ylabel='Quantity'>

# %%
sns.scatterplot(x = 'Gender', y = 'Age', data = df2)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
df2[df2['Age']>110]
# Out:
#     Age       Income  Gender Product  Quantity
# 98  120  34584.33704  Female       C         5

# %%
df2.drop(98, axis = 0, inplace = True)
# Out:
# /var/folders/ht/6xpr92fx6hb_qsdf6ml3w35w0000gn/T/ipykernel_3772/3437772263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(98, axis = 0, inplace = True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93 entries, 0 to 97
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       93 non-null     int64
#  1   Income    83 non-null     float64
#  2   Gender    93 non-null     object
#  3   Product   93 non-null     object
#  4   Quantity  93 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.4+ KB

# %%
sns.boxplot(x = 'Gender', y = 'Income', data = df2)
sns.set(rc={"figure.figsize":(9, 9
                        )})

# %%
df2[df2['Income']>90000]
# Out:
#     Age       Income  Gender Product  Quantity
# 49   37  94154.95125  Female       D         5

# %%
df2.drop(49, axis = 0, inplace = True)
# Out:
# /var/folders/ht/6xpr92fx6hb_qsdf6ml3w35w0000gn/T/ipykernel_3772/2759387740.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(49, axis = 0, inplace = True)

# %%
import matplotlib.pyplot as plt

# %%
df2.hist(figsize=(12, 10))
plt.show()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92 entries, 0 to 97
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       92 non-null     int64
#  1   Income    82 non-null     float64
#  2   Gender    92 non-null     object
#  3   Product   92 non-null     object
#  4   Quantity  92 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.3+ KB

# %%
df2['Income'].fillna(df2['Income'].mean(), inplace=True)
# Out:
# /var/folders/ht/6xpr92fx6hb_qsdf6ml3w35w0000gn/T/ipykernel_3772/2188858564.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Income'].fillna(df2['Income'].mean(), inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92 entries, 0 to 97
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       92 non-null     int64
#  1   Income    92 non-null     float64
#  2   Gender    92 non-null     object
#  3   Product   92 non-null     object
#  4   Quantity  92 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.3+ KB

# %%
df2.loc[df2['Income'] < 0, 'Income'] = df2['Income'].median()

# %%
df2.head()
# Out:
#    Age       Income  Gender Product  Quantity
# 0   56  59544.57663  Female       D         3
# 2   32  57140.63881  Female       D         2
# 3   60  69554.91903    Male       C         5
# 4   25  53173.80518  Female       D         2
# 5   38  58955.66969  Female       A         2

# %%
df2.groupby('Product')['Gender'].count()
# Out:
# Product
# A    22
# B    22
# C    22
# D    26
# Name: Gender, dtype: int64

# %%
df2['Income'].isnull().values.any()
# Out:
# False

# %%
sns.boxplot(x = 'Age', y = 'Income', data = df2)
sns.set(rc={"figure.figsize":(14, 14)})

# %%
df2[(df2['Age'] == 38) & (df2['Income']>55000)]
# Out:
#    Age       Income  Gender Product  Quantity
# 5   38  58955.66969  Female       A         2

# %%
df2.drop(5, axis = 0, inplace = True)
# Out:
# /var/folders/ht/6xpr92fx6hb_qsdf6ml3w35w0000gn/T/ipykernel_3772/3012021041.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(5, axis = 0, inplace = True)

# %%
df2[(df2['Age'] == 61) & (df2['Income']<30000)]
# Out:
#     Age       Income Gender Product  Quantity
# 69   61  20901.33172   Male       C         5

# %%
df2.drop(69, axis = 0, inplace = True)
# Out:
# /var/folders/ht/6xpr92fx6hb_qsdf6ml3w35w0000gn/T/ipykernel_3772/2047497633.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(69, axis = 0, inplace = True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 0 to 97
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       90 non-null     int64
#  1   Income    90 non-null     float64
#  2   Gender    90 non-null     object
#  3   Product   90 non-null     object
#  4   Quantity  90 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.2+ KB

# %%
sns.boxplot(x = 'Product', y = 'Quantity', data = df2)
sns.set(rc={"figure.figsize":(14, 14)})

# %%
df2[(df2['Product'] == 'A') & (df2['Quantity']<3)]
# Out:
#     Age        Income  Gender Product  Quantity
# 31   45  62355.996150    Male       A         2
# 39   38  50082.285012    Male       A         1
# 79   57  58152.330370  Female       A         2

# %%
df2.drop(31, axis = 0, inplace = True)
df2.drop(39, axis = 0, inplace = True)
df2.drop(79, axis = 0, inplace = True)
# Out:
# /var/folders/ht/6xpr92fx6hb_qsdf6ml3w35w0000gn/T/ipykernel_3772/769156751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(31, axis = 0, inplace = True)
# /var/folders/ht/6xpr92fx6hb_qsdf6ml3w35w0000gn/T/ipykernel_3772/769156751.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(39, axis = 0, inplace = True)
# /var/folders/ht/6xpr92fx6hb_qsdf6ml3w35w0000gn/T/ipykernel_3772/769156751.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87 entries, 0 to 97
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       87 non-null     int64
#  1   Income    87 non-null     float64
#  2   Gender    87 non-null     object
#  3   Product   87 non-null     object
#  4   Quantity  87 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.1+ KB

# %%
sns.boxplot(x = 'Product', y = 'Income', data = df2)
# Out:
# <Axes: xlabel='Product', ylabel='Income'>

# %%
df2[(df2['Product'] == 'B') & (df2['Income']>70000)]
# Out:
#     Age       Income Gender Product  Quantity
# 68   43  79475.52146   Male       B         1

# %%
df2.drop(68, axis = 0, inplace = True)
# Out:
# /var/folders/ht/6xpr92fx6hb_qsdf6ml3w35w0000gn/T/ipykernel_3772/284868978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(68, axis = 0, inplace = True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86 entries, 0 to 97
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       86 non-null     int64
#  1   Income    86 non-null     float64
#  2   Gender    86 non-null     object
#  3   Product   86 non-null     object
#  4   Quantity  86 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ KB

# %%
sns.boxplot(x = 'Age', y = 'Quantity', data = df2)
# Out:
# <Axes: xlabel='Age', ylabel='Quantity'>

# %%
df2[(df2['Age'] == 41) & (df2['Quantity'] == 1)]
# Out:
#     Age       Income  Gender Product  Quantity
# 85   41  39765.47654  Female       D         1

# %%
df2.drop(85, axis = 0, inplace = True)
# Out:
# /var/folders/ht/6xpr92fx6hb_qsdf6ml3w35w0000gn/T/ipykernel_3772/680193078.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(85, axis = 0, inplace = True)

# %%
df2[(df2['Age'] == 19) & (df2['Quantity'] == 4)]
# Out:
#     Age       Income  Gender Product  Quantity
# 22   19  52257.33617  Female       B         4

# %%
df2.drop(22, axis = 0, inplace = True)
# Out:
# /var/folders/ht/6xpr92fx6hb_qsdf6ml3w35w0000gn/T/ipykernel_3772/3090494733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(22, axis = 0, inplace = True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84 entries, 0 to 97
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       84 non-null     int64
#  1   Income    84 non-null     float64
#  2   Gender    84 non-null     object
#  3   Product   84 non-null     object
#  4   Quantity  84 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 3.9+ KB

# %%
sns.barplot(x = 'Age', y = 'Income', data = df2)
# Out:
# <Axes: xlabel='Age', ylabel='Income'>

# %%
sns.barplot(x = 'Gender', y = 'Income', data = df2)
# Out:
# <Axes: xlabel='Gender', ylabel='Income'>

# %%
sns.barplot(x = 'Product', y = 'Quantity', data = df2)
# Out:
# <Axes: xlabel='Product', ylabel='Quantity'>

# %%
sns.barplot(x = 'Gender', y = 'Quantity', hue = 'Product', data = df2)
# Out:
# <Axes: xlabel='Gender', ylabel='Quantity'>
