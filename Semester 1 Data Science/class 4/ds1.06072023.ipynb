# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/mahinbindra/Downloads/new_data.csv")

# %%
df.describe()
# Out:
#          Unnamed: 0    product_id   category_id         price       user_id
# count  1.000000e+07  1.000000e+07  1.000000e+07  1.000000e+07  1.000000e+07
# mean   5.000000e+06  1.100008e+07  2.057828e+18  2.925741e+02  5.354292e+08
# std    2.886751e+06  1.228346e+07  1.943274e+16  3.538111e+02  2.037214e+07
# min    0.000000e+00  1.000365e+06  2.053014e+18  0.000000e+00  1.030022e+07
# 25%    2.500000e+06  1.005252e+06  2.053014e+18  6.667000e+01  5.159950e+08
# 50%    5.000000e+06  5.100722e+06  2.053014e+18  1.653100e+02  5.306267e+08
# 75%    7.499999e+06  1.640001e+07  2.053014e+18  3.654600e+02  5.548916e+08
# max    9.999999e+06  6.210003e+07  2.180737e+18  2.574070e+03  5.684226e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 10 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Unnamed: 0     int64
#  1   event_time     object
#  2   event_type     object
#  3   product_id     int64
#  4   category_id    int64
#  5   category_code  object
#  6   brand          object
#  7   price          float64
#  8   user_id        int64
#  9   user_session   object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 762.9+ MB

# %%
df.head(10)
# Out:
#    Unnamed: 0               event_time event_type  product_id
# 0           0  2019-11-01 00:00:00 UTC       view     1003461  \
# 1           1  2019-11-01 00:00:00 UTC       view     5000088
# 2           2  2019-11-01 00:00:01 UTC       view    17302664
# 3           3  2019-11-01 00:00:01 UTC       view     3601530
# 4           4  2019-11-01 00:00:01 UTC       view     1004775
# 5           5  2019-11-01 00:00:01 UTC       view     1306894
# 6           6  2019-11-01 00:00:01 UTC       view     1306421
# 7           7  2019-11-01 00:00:02 UTC       view    15900065
# 8           8  2019-11-01 00:00:02 UTC       view    12708937
# 9           9  2019-11-01 00:00:02 UTC       view     1004258
#
#            category_id              category_code     brand   price
# 0  2053013555631882655     electronics.smartphone    xiaomi  489.07  \
# 1  2053013566100866035  appliances.sewing_machine    janome  293.65
# 2  2053013553853497655                        NaN     creed   28.31
# ...

# %%
df.loc[df['brand'].isnull()]
# Out:
#          Unnamed: 0               event_time event_type  product_id
# 10               10  2019-11-01 00:00:03 UTC       view    17200570  \
# 11               11  2019-11-01 00:00:03 UTC       view     2701517
# 12               12  2019-11-01 00:00:03 UTC       view    16700260
# 13               13  2019-11-01 00:00:04 UTC       view    34600011
# 15               15  2019-11-01 00:00:06 UTC       view    24900193
# ...             ...                      ...        ...         ...
# 9999951     9999951  2019-11-07 05:08:19 UTC       view    17300339
# 9999963     9999963  2019-11-07 05:08:19 UTC       view    17200454
# 9999975     9999975  2019-11-07 05:08:20 UTC       view    25200032
# 9999992     9999992  2019-11-07 05:08:21 UTC       view    28716717
# 9999993     9999993  2019-11-07 05:08:21 UTC       view    15901409
#
#                  category_id                     category_code brand   price
# ...

# %%
df['event_type'] =='remove_from_cart'
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 9999995    False
# 9999996    False
# 9999997    False
# 9999998    False
# 9999999    False
# Name: event_type, Length: 10000000, dtype: bool

# %%
df
# Out:
#          Unnamed: 0               event_time event_type  product_id
# 0                 0  2019-11-01 00:00:00 UTC   purchase     1003461  \
# 1                 1  2019-11-01 00:00:00 UTC   purchase     5000088
# 2                 2  2019-11-01 00:00:01 UTC   purchase    17302664
# 3                 3  2019-11-01 00:00:01 UTC   purchase     3601530
# 4                 4  2019-11-01 00:00:01 UTC   purchase     1004775
# ...             ...                      ...        ...         ...
# 9999995     9999995  2019-11-07 05:08:21 UTC   purchase     1005115
# 9999996     9999996  2019-11-07 05:08:21 UTC   purchase    12707281
# 9999997     9999997  2019-11-07 05:08:21 UTC   purchase     3601405
# 9999998     9999998  2019-11-07 05:08:21 UTC   purchase    12711053
# 9999999     9999999  2019-11-07 05:08:21 UTC   purchase     1005121
#
#                  category_id              category_code     brand   price
# 0        2053013555631882655     electronics.smartphone    xiaomi  489.07  \
# ...

# %%
df2 = df.dropna(subset = ['brand'])

# %%
highestprice = df2.groupby('product_id')

# %%
df2.sort_values('price', ascending=False).head(10000)
# Out:
#          Unnamed: 0               event_time event_type  product_id
# 3675855     3675855  2019-11-03 10:22:06 UTC   purchase    21407288  \
# 4028433     4028433  2019-11-03 14:23:38 UTC   purchase    21407288
# 4238596     4238596  2019-11-03 17:18:05 UTC   purchase    21407288
# 5540754     5540754  2019-11-04 13:16:06 UTC   purchase    21407288
# 1697870     1697870  2019-11-02 05:47:31 UTC   purchase    21407288
# ...             ...                      ...        ...         ...
# 8309909     8309909  2019-11-06 05:32:50 UTC   purchase     1305977
# 9886484     9886484  2019-11-07 03:33:59 UTC   purchase     1305977
# 8456787     8456787  2019-11-06 07:14:15 UTC   purchase     1305977
# 9102245     9102245  2019-11-06 14:17:16 UTC   purchase     1305977
# 9798885     9798885  2019-11-07 01:36:42 UTC   purchase     1305977
#
#                  category_id       category_code  brand    price    user_id
# ...

# %%
df_mostsales = df.groupby('product_id').sum().sort_values('price')
